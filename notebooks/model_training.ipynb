# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
users = pd.read_csv("data/Users.csv", index_col=False)
books = pd.read_csv("data/Books.csv", index_col=False)
ratings = pd.read_csv("data/Ratings.csv", index_col=False)
# Out:
# /tmp/ipykernel_10400/34815975.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("data/Books.csv", index_col=False)

# %% [markdown]
# ## Popularity Based Recommender

# %%
ratings_with_title = ratings.merge(books,on='ISBN')
ratings_with_title.head()
# Out:
#    User-ID        ISBN  Book-Rating  Unnamed: 0            Book-Title  \
# 0   276725  034545104X            0        2966  Flesh Tones: A Novel
# 1     2313  034545104X            5        2966  Flesh Tones: A Novel
# 2     6543  034545104X            0        2966  Flesh Tones: A Novel
# 3     8680  034545104X            5        2966  Flesh Tones: A Novel
# 4    10314  034545104X            9        2966  Flesh Tones: A Novel
#
#   Book-Author Year-Of-Publication         Publisher  \
# 0  M. J. Rose                2002  Ballantine Books
# 1  M. J. Rose                2002  Ballantine Books
# 2  M. J. Rose                2002  Ballantine Books
# 3  M. J. Rose                2002  Ballantine Books
# 4  M. J. Rose                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...

# %% [markdown]
# finding num of ratings for each book

# %%
num_rating_df = ratings_with_title.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating': 'num_rating'}, inplace=True)
num_rating_df.head()
# Out:
#                                           Book-Title  num_rating
# 0   A Light in the Storm: The Civil War Diary of ...           4
# 1                              Always Have Popsicles           1
# 2               Apple Magic (The Collector's series)           1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4   Beyond IBM: Leadership Marketing and Finance ...           1

# %% [markdown]
# finding average rating of each book

# %%
avg_rating_df = ratings_with_title.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)
avg_rating_df.head()
# Out:
# /tmp/ipykernel_10400/1200090740.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_title.groupby('Book-Title').mean()['Book-Rating'].reset_index()
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %% [markdown]
# making new dataframe of popular books which have more than 100 ratings on them

# %%
popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title')
popular_df = popular_df[popular_df['num_rating'] >= 100].sort_values('avg_rating', ascending=False).head(50)
popular_df.head()
# Out:
#                                                Book-Title  num_rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 195672                                  The Little Prince         141
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
#
#         avg_rating
# 80434     5.852804
# 80422     5.824289
# 195672    5.815603
# 80441     5.737410
# 80426     5.501441

# %% [markdown]
# merging popular book dataframe to original dataframe to extract more info about each book

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_rating', 'avg_rating']]
popular_df.head()
# Out:
#                                            Book-Title  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)
# 3        Harry Potter and the Goblet of Fire (Book 4)
# 5                                   The Little Prince
# 10     Harry Potter and the Sorcerer's Stone (Book 1)
# 14  Harry Potter and the Order of the Phoenix (Boo...
#
#                   Book-Author  \
# 0               J. K. Rowling
# 3               J. K. Rowling
# 5   Antoine de Saint-Exup̩ry
# 10              J. K. Rowling
# 14              J. K. Rowling
#
#                                           Image-URL-M  num_rating  avg_rating
# 0   http://images.amazon.com/images/P/0439136350.0...         428    5.852804
# 3   http://images.amazon.com/images/P/0439139597.0...         387    5.824289
# 5   http://images.amazon.com/images/P/0156528207.0...         141    5.815603
# 10  http://images.amazon.com/images/P/0590353403.0...         278    5.737410
# 14  http://images.amazon.com/images/P/043935806X.0...         347    5.501441

# %% [markdown]
# ## Collaborative based filtering

# %% [markdown]
# finiding users who have participated in more than 200 ratings

# %%
x = ratings_with_title.groupby('User-ID').count()['Book-Rating'] > 200
trusted_user = x[x].index
trusted_user
# Out:
# Int64Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,
#               6323,   6543,
#             ...
#             271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427,
#             277639, 278418],
#            dtype='int64', name='User-ID', length=811)

# %%
trusted_user.shape
# Out:
# (811,)

# %%
filtered_ratings = ratings_with_title[ratings_with_title['User-ID'].isin(trusted_user)]
filtered_ratings.head()
# Out:
#     User-ID        ISBN  Book-Rating  Unnamed: 0            Book-Title  \
# 2      6543  034545104X            0        2966  Flesh Tones: A Novel
# 5     23768  034545104X            0        2966  Flesh Tones: A Novel
# 7     28523  034545104X            0        2966  Flesh Tones: A Novel
# 15    77940  034545104X            0        2966  Flesh Tones: A Novel
# 16    81977  034545104X            0        2966  Flesh Tones: A Novel
#
#    Book-Author Year-Of-Publication         Publisher  \
# 2   M. J. Rose                2002  Ballantine Books
# 5   M. J. Rose                2002  Ballantine Books
# 7   M. J. Rose                2002  Ballantine Books
# 15  M. J. Rose                2002  Ballantine Books
# 16  M. J. Rose                2002  Ballantine Books
#
#                                           Image-URL-S  \
# 2   http://images.amazon.com/images/P/034545104X.0...
# 5   http://images.amazon.com/images/P/034545104X.0...
# 7   http://images.amazon.com/images/P/034545104X.0...
# 15  http://images.amazon.com/images/P/034545104X.0...
# 16  http://images.amazon.com/images/P/034545104X.0...
#
#                                           Image-URL-M  \
# 2   http://images.amazon.com/images/P/034545104X.0...
# 5   http://images.amazon.com/images/P/034545104X.0...
# 7   http://images.amazon.com/images/P/034545104X.0...
# 15  http://images.amazon.com/images/P/034545104X.0...
# 16  http://images.amazon.com/images/P/034545104X.0...
#
#                                           Image-URL-L
# 2   http://images.amazon.com/images/P/034545104X.0...
# 5   http://images.amazon.com/images/P/034545104X.0...
# 7   http://images.amazon.com/images/P/034545104X.0...
# 15  http://images.amazon.com/images/P/034545104X.0...
# 16  http://images.amazon.com/images/P/034545104X.0...

# %%
y = filtered_ratings.groupby('Book-Title').count()['Book-Rating'] >= 50
trusted_books = y[y].index
trusted_books.unique()
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
trusted_books.shape
# Out:
# (706,)

# %%
filtered_books = filtered_ratings[filtered_ratings['Book-Title'].isin(trusted_books)]
filtered_books.head()
# Out:
#     User-ID        ISBN  Book-Rating  Unnamed: 0    Book-Title  \
# 63   278418  0446520802            0       11053  The Notebook
# 65     3363  0446520802            0       11053  The Notebook
# 66     7158  0446520802           10       11053  The Notebook
# 69    11676  0446520802           10       11053  The Notebook
# 74    23768  0446520802            6       11053  The Notebook
#
#         Book-Author Year-Of-Publication     Publisher  \
# 63  Nicholas Sparks                1996  Warner Books
# 65  Nicholas Sparks                1996  Warner Books
# 66  Nicholas Sparks                1996  Warner Books
# 69  Nicholas Sparks                1996  Warner Books
# 74  Nicholas Sparks                1996  Warner Books
#
#                                           Image-URL-S  \
# 63  http://images.amazon.com/images/P/0446520802.0...
# 65  http://images.amazon.com/images/P/0446520802.0...
# 66  http://images.amazon.com/images/P/0446520802.0...
# 69  http://images.amazon.com/images/P/0446520802.0...
# 74  http://images.amazon.com/images/P/0446520802.0...
#
#                                           Image-URL-M  \
# 63  http://images.amazon.com/images/P/0446520802.0...
# 65  http://images.amazon.com/images/P/0446520802.0...
# 66  http://images.amazon.com/images/P/0446520802.0...
# 69  http://images.amazon.com/images/P/0446520802.0...
# 74  http://images.amazon.com/images/P/0446520802.0...
#
#                                           Image-URL-L
# 63  http://images.amazon.com/images/P/0446520802.0...
# 65  http://images.amazon.com/images/P/0446520802.0...
# 66  http://images.amazon.com/images/P/0446520802.0...
# 69  http://images.amazon.com/images/P/0446520802.0...
# 74  http://images.amazon.com/images/P/0446520802.0...

# %%
filtered_books.shape
# Out:
# (58586, 11)

# %%
pt = filtered_books.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [706 rows x 810 columns]

# %%
similarity_scores = cosine_similarity(pt)

# %%
import pickle

pickle.dump(popular_df,open('data/popular.pkl','wb'))
pickle.dump(pt,open('data/pt.pkl','wb'))
pickle.dump(books,open('data/books.pkl','wb'))
pickle.dump(similarity_scores,open('data/similarity_scores.pkl','wb'))

# %%
def recommend(input_book,top):
    index = np.where(pt.index==input_book)[0][0]
    suggestion = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:top]
    suggestion_top = [pt.index[i[0]] for i in suggestion]
    book_title = []
    book_author = []
    book_image = []
    for book in suggestion_top:
        temp_df = books.loc[books['Book-Title'] == book].drop_duplicates('Book-Title')
        book_title.extend(list(temp_df['Book-Title'].values))
        book_author.extend(list(temp_df['Book-Author'].values))
        book_image.extend(list(temp_df['Image-URL-M'].values))
        rec_colab = list(zip(book_title, book_author, book_image))
    return rec_colab
